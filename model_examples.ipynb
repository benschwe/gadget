# %%
from model import Gadget
from simulation import Simulation
from matplotlib import pyplot as plt
import numpy as np
from plotting import plot_fissions_and_energy, plot_conc_and_surf_flux, plot_radial_concentration, plot_neutron_counts

# %%
gadget = Gadget(
           id=0,
           material='U235',
           initial_radius_cm=8.3,
           initial_neutron_conc_perm3=0,
           initial_neutron_burst_conc_perm3=50000,
           time_step_s=1E-10, 
           num_points_radial=100,
           neutron_multiplication_on=True
           )

initial_radius_list = [8.0, 8.2, 8.35, 8.5]

gadget_list = []
for initial_radius in initial_radius_list:
    gadget_list.append(Gadget(id=initial_radius,
                              initial_radius_cm=initial_radius))

sim = Simulation(gadget_list=gadget_list,
                 sim_duration_us=5,
                 stop_when_nuclei_limit_met=True
                 )

sim.run_gadgets()
# Out:
# Number of sim steps in all simulations: 50000
#
# Running gadget ID: 8.0
# Elapsed simulation time for gadget 8.0: 1040 ms
# Not critical
# ---------------
# Running gadget ID: 8.2
# Elapsed simulation time for gadget 8.2: 900 ms
# Not critical
# ---------------
# Running gadget ID: 8.35
# Elapsed simulation time for gadget 8.35: 815 ms
# Critical
# ---------------
# Running gadget ID: 8.5
# Elapsed simulation time for gadget 8.5: 736 ms
# Critical
# ---------------

# %%
plot_conc_and_surf_flux(gadget=gadget_list[3])
plot_radial_concentration(gadget=gadget_list[3])
plot_neutron_counts(gadget=gadget_list[3])
plot_fissions_and_energy(gadget_list=gadget_list)
