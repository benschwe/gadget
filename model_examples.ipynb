# %%
from model import Gadget
from simulation import Simulation
from matplotlib import pyplot as plt
import numpy as np
from plotting import plot_fission_rate_and_energy, plot_conc_and_surf_flux, plot_radial_concentration, plot_neutron_counts

# %%
gadget = Gadget(
           id=0,
           material='U235',
           initial_radius_cm=8.3,
           initial_neutron_conc_perm3=0,
           initial_neutron_burst_conc_perm3=50000,
           time_step_s=1E-10, 
           num_points_radial=100,
           neutron_multiplication_on=True
           )

initial_radius_list = [8.2]

gadget_list = []
for initial_radius in initial_radius_list:
    gadget_list.append(Gadget(id=initial_radius,
                              initial_radius_cm=initial_radius))

sim = Simulation(gadget_list=gadget_list,
                 sim_duration_us=1,
                 stop_when_nuclei_limit_met=True
                 )

sim.run_gadgets()
# Out:
# Number of sim steps in all simulations: 10000
#
# Running gadget ID: 8.2
# Elapsed simulation time for gadget 8.2: 201 ms
# Not critical
# ---------------

# %%
gadget_list[0].sim_time_array_s.size
# Out:
# 10001

# %%
plot_conc_and_surf_flux(gadget=gadget_list[0])
plot_radial_concentration(gadget=gadget_list[0])
plot_neutron_counts(gadget=gadget_list[0])
plot_fission_rate_and_energy(gadget_list=gadget_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       2 plot_radial_concentration(gadget=gadget_list[0])
#       3 plot_neutron_counts(gadget=gadget_list[0])
# ----> 4 plot_fission_rate_and_energy(gadget_list=gadget_list)
#
# File ~/Documents/Code/gadget/plotting.py:14, in plot_fission_rate_and_energy(gadget_list)
#       9 fig, ax = plt.subplots(2, 1, sharex=True, figsize = (8, 8))
#      11 for g in gadget_list:
#      12
#      13     # Fission rate
# ---> 14     ax[0].plot(g.sim_time_array_us, g.array_fission_rate_pers)
#      16     # Total energy (kt)
#      17     ax[1].plot(g.sim_time_array_us, g.array_total_energy_released_kt,
#      18                label = 'ID: ' + str(g.id) + ', ' + str(g.initial_radius_cm) + ' cm')
#
# AttributeError: 'Gadget' object has no attribute 'array_fission_rate_pers'
